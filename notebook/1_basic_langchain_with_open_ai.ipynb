# %%
 # %pip install langchain-openai python-dotenv
# Out:
# Collecting langchain-openai
#   Obtaining dependency information for langchain-openai from https://files.pythonhosted.org/packages/2f/4b/7520114de1ce36bb17cbc98d0fcda048a9f755bedaeb73b92137aeaaf1db/langchain_openai-1.3.3-py3-none-any.whl.metadata
#   Using cached langchain_openai-1.3.3-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: python-dotenv in d:\projects\gen_ai\env\lib\site-packages (1.2.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.7 in d:\projects\gen_ai\env\lib\site-packages (from langchain-openai) (1.4.8)
# Collecting openai<3.0.0,>=2.26.0 (from langchain-openai)
#   Obtaining dependency information for openai<3.0.0,>=2.26.0 from https://files.pythonhosted.org/packages/ae/f4/561ed79fd94876160018a5e75254cfcb9b0e62d4dded9dcb20072e86d623/openai-2.44.0-py3-none-any.whl.metadata
#   Using cached openai-2.44.0-py3-none-any.whl.metadata (34 kB)
# Collecting tiktoken<1.0.0,>=0.7.0 (from langchain-openai)
#   Obtaining dependency information for tiktoken<1.0.0,>=0.7.0 from https://files.pythonhosted.org/packages/aa/90/28d7f154888610aa9237e541986beb62b479df29d193a5a0617dbb1514d0/tiktoken-0.13.0-cp312-cp312-win_amd64.whl.metadata
#   Using cached tiktoken-0.13.0-cp312-cp312-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\projects\gen_ai\env\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain-openai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in d:\projects\gen_ai\env\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain-openai) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\projects\gen_ai\env\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain-openai) (0.9.2)
# Requirement already satisfied: packaging>=23.2.0 in d:\projects\gen_ai\env\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain-openai) (26.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\projects\gen_ai\env\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain-openai) (2.13.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\projects\gen_ai\env\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain-openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\projects\gen_ai\env\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain-openai) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in d:\projects\gen_ai\env\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain-openai) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\projects\gen_ai\env\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain-openai) (0.16.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in d:\projects\gen_ai\env\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (4.14.1)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\projects\gen_ai\env\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\projects\gen_ai\env\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (0.28.1)
# Collecting jiter<1,>=0.10.0 (from openai<3.0.0,>=2.26.0->langchain-openai)
#   Obtaining dependency information for jiter<1,>=0.10.0 from https://files.pythonhosted.org/packages/95/bf/8ead82a87495149542748e828d153fd232a512a22c83b02c4815c1a9c7d8/jiter-0.15.0-cp312-cp312-win_amd64.whl.metadata
#   Downloading jiter-0.15.0-cp312-cp312-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: sniffio in d:\projects\gen_ai\env\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.3.1)
# Collecting tqdm>4 (from openai<3.0.0,>=2.26.0->langchain-openai)
#   Obtaining dependency information for tqdm>4 from https://files.pythonhosted.org/packages/d8/8e/bb97bb0c71802080bfc8952937d174e49cfc50de5c951dd47b2496f0dcdb/tqdm-4.68.3-py3-none-any.whl.metadata
#   Downloading tqdm-4.68.3-py3-none-any.whl.metadata (57 kB)
#      ---------------------------------------- 0.0/57.4 kB ? eta -:--:--
#      ------------- ------------------------ 20.5/57.4 kB 640.0 kB/s eta 0:00:01
#      -------------------------------------- 57.4/57.4 kB 747.9 kB/s eta 0:00:00
# Collecting regex (from tiktoken<1.0.0,>=0.7.0->langchain-openai)
#   Obtaining dependency information for regex from https://files.pythonhosted.org/packages/78/87/240d36864f9e48ace85f72e79ced97ceb7f27ce87739a947dcb834b4e6bc/regex-2026.5.9-cp312-cp312-win_amd64.whl.metadata
#   Downloading regex-2026.5.9-cp312-cp312-win_amd64.whl.metadata (41 kB)
#      ---------------------------------------- 0.0/41.5 kB ? eta -:--:--
#      ---------------------------------------  41.0/41.5 kB ? eta -:--:--
#      ---------------------------------------- 41.5/41.5 kB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: requests in d:\projects\gen_ai\env\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.34.2)
# Requirement already satisfied: idna>=2.8 in d:\projects\gen_ai\env\lib\site-packages (from anyio<5,>=3.5.0->openai<3.0.0,>=2.26.0->langchain-openai) (3.18)
# Requirement already satisfied: certifi in d:\projects\gen_ai\env\lib\site-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=2.26.0->langchain-openai) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in d:\projects\gen_ai\env\lib\site-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=2.26.0->langchain-openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\projects\gen_ai\env\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<3.0.0,>=2.26.0->langchain-openai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\projects\gen_ai\env\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.7->langchain-openai) (3.1.1)
# Requirement already satisfied: orjson>=3.9.14 in d:\projects\gen_ai\env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-openai) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\projects\gen_ai\env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-openai) (1.0.0)
# Requirement already satisfied: websockets>=15.0 in d:\projects\gen_ai\env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-openai) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in d:\projects\gen_ai\env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-openai) (3.7.1)
# Requirement already satisfied: zstandard>=0.23.0 in d:\projects\gen_ai\env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-openai) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\projects\gen_ai\env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.4.7->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in d:\projects\gen_ai\env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.4.7->langchain-openai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\projects\gen_ai\env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.4.7->langchain-openai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\projects\gen_ai\env\lib\site-packages (from requests->tiktoken<1.0.0,>=0.7.0->langchain-openai) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in d:\projects\gen_ai\env\lib\site-packages (from requests->tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.7.0)
# Requirement already satisfied: colorama in d:\projects\gen_ai\env\lib\site-packages (from tqdm>4->openai<3.0.0,>=2.26.0->langchain-openai) (0.4.6)
# Using cached langchain_openai-1.3.3-py3-none-any.whl (120 kB)
# Using cached openai-2.44.0-py3-none-any.whl (1.4 MB)
# Using cached tiktoken-0.13.0-cp312-cp312-win_amd64.whl (874 kB)
# Downloading jiter-0.15.0-cp312-cp312-win_amd64.whl (197 kB)
#    ---------------------------------------- 0.0/197.3 kB ? eta -:--:--
#    ------------ --------------------------- 61.4/197.3 kB 1.7 MB/s eta 0:00:01
#    -------------- ------------------------ 71.7/197.3 kB 787.7 kB/s eta 0:00:01
#    ---------------------------------------  194.6/197.3 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 197.3/197.3 kB 1.1 MB/s eta 0:00:00
# Downloading tqdm-4.68.3-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.3 kB ? eta -:--:--
#    ------------------------------- -------- 61.4/78.3 kB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 78.3/78.3 kB 1.5 MB/s eta 0:00:00
# Downloading regex-2026.5.9-cp312-cp312-win_amd64.whl (277 kB)
#    ---------------------------------------- 0.0/277.8 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/277.8 kB 640.0 kB/s eta 0:00:01
#    ---------------------- ----------------- 153.6/277.8 kB 1.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 153.6/277.8 kB 1.5 MB/s eta 0:00:01
#    --------------------------------- ------ 235.5/277.8 kB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  276.5/277.8 kB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 277.8/277.8 kB 1.0 MB/s eta 0:00:00
# Installing collected packages: tqdm, regex, jiter, tiktoken, openai, langchain-openai
# Successfully installed jiter-0.15.0 langchain-openai-1.3.3 openai-2.44.0 regex-2026.5.9 tiktoken-0.13.0 tqdm-4.68.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# basic chatbot using openai and 
# first step is install dotenv for the env load
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")
prompt=[("system","You are c++ devloper"),          # this is a way by how you shold give the prompt
        ("user","which library file added at top")]
res = llm.invoke(prompt)
print(res.content)
# Out:
# As a C++ developer, when you say "library file added at top," you are almost certainly referring to **header files** (or header-only libraries) which are included using the **`#include` preprocessor directive**.
#
# These header files provide declarations for functions, classes, macros, templates, and other entities that are defined elsewhere (either in the standard library, other source files within your project, or external libraries).
#
# ### Why and How are they added at the top?
#
# 1.  **Purpose:** Header files tell the compiler what functions, classes, etc., are available to use. Without these declarations, the compiler wouldn't know how to interpret calls to library functions or uses of library classes, resulting in compilation errors.
# 2.  **Location:** They are typically placed at the top of your `.cpp` source files (or other header files) because the declarations they contain are usually needed by the code that follows them. The preprocessor effectively "copies and pastes" the content of the included file into your source file at that point.
# 3.  **Syntax:**
#     *   **For Standard Library Headers (or system-wide headers):** You use angle brackets (`<>`). The compiler searches predefined system paths for these.
#         ```cpp
#         #include <iostream>   // For input/output operations (e.g., std::cout, std::cin)
#         #include <string>     // For std::string class
#         #include <vector>     // For std::vector container
#         #include <algorithm>  // For various algorithms (e.g., std::sort, std::find)
#         #include <cmath>      // For mathematical functions (e.g., std::sqrt, std::pow)
#         #include <fstream>    // For file input/output (e.g., std::ifstream, std::ofstream)
#         ```
#     *   **For Your Own Project's Headers (or third-party headers in your project directory):** You use double quotes (`""`). The compiler typically searches the current directory first, then other specified include paths.
#         ```cpp
#         #include "my_utility_functions.h" // A header file you created for your project
#         #include "MyClass.hpp"            // Another custom header
#         ```
#
# ### Example:
#
# ```cpp
# // 1. Standard Library Headers
# #include <iostream> // Provides std::cout, std::endl
# #include <string>   // Provides std::string
# #include <vector>   // Provides std::vector
#
# // 2. Custom Project Header (assuming "my_math.h" exists in the same directory)
# #include "my_math.h" // Might declare a function like 'add(int a, int b)'
#
# int main() {
#     std::string name = "C++ Developer";
#     std::cout << "Hello, " << name << "!" << std::endl;
#
#     std::vector<int> numbers = {1, 2, 3, 4, 5};
#     // ... use numbers ...
#
#     // int sum = add(10, 20); // If my_math.h declared 'add'
#     // std::cout << "Sum: " << sum << std::endl;
#
#     return 0;
# }
# ```
#
# ### Important Distinction:
#
# It's important to differentiate this from **linking** against a compiled library (`.lib`, `.a`, `.so`, `.dll`).
# *   **`#include` (Header Files):** This happens at **compile-time**. It brings in *declarations* so your code knows *how* to use functions/classes.
# *   **Linking (Compiled Libraries):** This happens at **link-time**. It connects your compiled code with the actual *implementations* (definitions) of those functions/classes found in the pre-compiled library files. You typically specify these libraries to your compiler/linker via command-line flags (e.g., `-lmy_library`) or project settings in an IDE.
