# %%
import os
from dotenv import load_dotenv
load_dotenv()

from langchain_groq import ChatGroq
llm=ChatGroq(model="openai/gpt-oss-20b")

res=llm.invoke("who is president of us")
print(res.content)
# Out:
# As of the most recent information I have (up to the 2024 election cycle), **Joe Biden** is the President of the United States.
# If you need the absolute latest status—especially if you’re asking about 2026—you might want to double‑check a current news source or the official White House website, as the presidency could have changed since my last update.
