# %%
import os
from dotenv import load_dotenv
load_dotenv()

from langchain_groq import ChatGroq
llm=ChatGroq(model="openai/gpt-oss-20b",streaming=True)

res=llm.stream("What is gen ai")
for i in res:
    print(i.content,end=" ")
# Out:
#                        ** Gener ative  AI  ( Gen  AI )**  is  a  branch  of  artificial  intelligence  that  focuses  on  creating  new  content — such  as  text ,  images ,  music ,  video ,  or  even  code — rather  than  simply  analyzing  or  class ifying  existing  data .  Below  is  a  concise  overview :
#
#  |  Aspect  |  What  it  Means  |  Common  Examples  |
#  | -------- | --------------- | ---------------- - |
#  |  ** Core  Idea **  |  Models  learn  patterns  from  large  datasets  and  then  * generate *  novel  outputs  that  resemble  the  training  data .  |  GPT ‑ 4  ( text ),  D ALL ‑ E   3  ( images ),  Stable  Diff usion  ( images ),  J uk ebox  ( music )  |
#  |  ** Technology **  |  Uses  deep  learning  architectures  like  Transformers ,  Diff usion  Models ,  GAN s ,  or  autore gressive  models .  |  Transformers  for  language ,  Diff usion  for  images ,  GAN s  for  realistic  photos  |
#  |  ** Training  Data **  |  Massive  corp ora  of  text ,  images ,  audio ,  etc .  |  Wikipedia ,  books ,  internet  text ;  Image Net ,  CO CO ,  etc .  |
#  |  ** Key  Features **  |  •  ** Creat ivity **  –  can  produce  something  never  seen  before .  < br > •  ** Vari ability **  –  can  generate  many  different  versions  of  a  prompt .  < br > •  ** Conditional  Generation **  –  can  tailor  output  based  on  user  prompts  or  constraints .  |  Chat GPT  answering  questions ,  Mid jour ney  creating  art ,  Cop ilot  generating  code  snippets  |
#  |  ** Applications **  |  •  Content  creation  ( articles ,  stories ,  artwork ).  < br > •  Design  &  prot otyping  ( logos ,  product  mock ‑ ups ).  < br > •  Entertainment  ( music ,  games ,  movies ).  < br > •  Assist ive  tech  ( coding  help ,  writing  assistance ).  |  Writing  assistance ,  AI ‑ dr iven  design  tools ,  automated  code  generation ,  creative  storytelling  |
#  |  ** Challenges **  |  •  ** Quality  &  Cons istency **  –  sometimes  outputs  are  nons ens ical  or  biased .  < br > •  ** Eth ics  &  Mis use **  –  deep f akes ,  misinformation ,  plagiarism .  < br > •  ** Comput ational  Cost **  –  training  large  models  requires  significant  resources .  |  Bias  in  text  generation ,  copyright  concerns ,  halluc inations  in  AI  responses  |
#
#  ###  How  It  Works  ( Simpl ified )
#
#  1 .  ** Data  Collection **  –  Gather  millions  of  examples  ( e .g .,  text ,  images ).
#  2 .  ** Model  Architecture **  –  Build  a  neural  network  ( often  a  Transformer  for  language ).
#  3 .  ** Training **  –  Adjust  weights  so  the  model  learns  to  predict  the  next  token  or  pixel .
#  4 .  ** Inference **  –  Given  a  prompt ,  the  model  generates  new  tokens /p ixels  step  by  step ,  producing  a  coherent  output .
#  5 .  ** Post ‑ processing **  –  Filter ,  refine ,  or  edit  the  generated  content  to  meet  user  needs .
#
#  ###  Quick  FAQ
#
#  |  Question  |  Answer  |
#  | ---------- | -------- |
#  |  ** Is  Gen  AI  the  same  as  AI ? **  |  Gen  AI  is  a  subset  of  AI  focused  on  * generation *  rather  than  classification  or  prediction .  |
#  |  ** Can  it  replace  human  creativity ? **  |  It  aug ments  human  creativity ,  offering  rapid  drafts  or  ideas ,  but  humans  still  guide  and  refine  the  output .  |
#  |  ** Is  it  safe ? **  |  It  can  produce  harmful  or  biased  content ;  responsible  use ,  moderation ,  and  ethical  guidelines  are  essential .  |
#  |  ** What ’s  the  difference  between  GPT ‑ 4  and  GPT ‑ 3 ? **  |  GPT ‑ 4  has  more  parameters ,  better  context  handling ,  and  improved  safety  features ,  leading  to  higher ‑ quality  responses .  |
#
#  ###  Bottom  Line
#
#  Gener ative  AI  is  the  technology  that  lets  machines  * create *  new ,  original  content  by  learning  patterns  from  vast  amounts  of  data .  It  powers  everything  from  chat bots  and  writing  assistants  to  AI ‑ dr iven  art  generators  and  code  helpers ,  resh aping  how  we  produce  and  interact  with  creative  media .
